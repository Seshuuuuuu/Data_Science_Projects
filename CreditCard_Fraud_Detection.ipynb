# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('creditcard.csv')

# %%
dataset.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
legit = dataset[dataset.Class == 0]
fraud = dataset[dataset.Class == 1]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 221880 entries, 0 to 221879
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    221880 non-null  float64
#  1   V1      221880 non-null  float64
#  2   V2      221880 non-null  float64
#  3   V3      221880 non-null  float64
#  4   V4      221880 non-null  float64
#  5   V5      221880 non-null  float64
#  6   V6      221880 non-null  float64
#  7   V7      221880 non-null  float64
#  8   V8      221880 non-null  float64
#  9   V9      221880 non-null  float64
#  10  V10     221880 non-null  float64
#  11  V11     221880 non-null  float64
#  12  V12     221880 non-null  float64
#  13  V13     221880 non-null  float64
#  14  V14     221880 non-null  float64
#  15  V15     221880 non-null  float64
#  16  V16     221880 non-null  float64
#  17  V17     221880 non-null  float64
#  18  V18     221880 non-null  float64
#  19  V19     221880 non-null  float64
#  20  V20     221880 non-null  float64
#  21  V21     221879 non-null  float64
#  22  V22     221879 non-null  float64
#  23  V23     221879 non-null  float64
#  24  V24     221879 non-null  float64
#  25  V25     221879 non-null  float64
#  26  V26     221879 non-null  float64
#  27  V27     221879 non-null  float64
#  28  V28     221879 non-null  float64
#  29  Amount  221879 non-null  float64
#  30  Class   221879 non-null  float64
# dtypes: float64(31)
# memory usage: 52.5 MB

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (221470, 31)
# (409, 31)

# %%
legit.Amount.describe()
# Out:
# count    221470.000000
# mean         90.693500
# std         250.895928
# min           0.000000
# 25%           6.000000
# 50%          23.400000
# 75%          79.950000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     409.000000
# mean      126.098924
# std       257.557417
# min         0.000000
# 25%         1.000000
# 50%        14.460000
# 75%       106.900000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    77317.731237 -0.064218 -0.018582  0.223183  0.041402 -0.064388
# 1.0    65815.268949 -5.435534  4.000800 -7.507748  4.668153 -3.834575
#
#              V6        V7        V8        V9  ...      V20       V21  \
# Class                                          ...
# 0.0    0.036238 -0.018102  0.004353  0.008579  ...  0.01130 -0.009093
# 1.0   -1.359844 -6.326941  0.653534 -2.699718  ...  0.38729  0.772642
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.027294 -0.011262  0.001487  0.042559  0.003308  0.000161  0.002093
# 1.0    0.009933 -0.054624 -0.082548  0.051201  0.041523  0.194965  0.060572
#
#            Amount
# Class
# 0.0     90.693500
# 1.0    126.098924
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample,fraud],axis=0)

# %%
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 45064    42191.0 -1.016813  1.284121  1.823947  2.704242 -0.355924 -0.324408
# 221763  142692.0  2.039300 -0.299143 -2.891240 -1.139530  1.393355 -0.015479
# 184315  126193.0  1.855917 -1.934586 -3.103106 -1.649222 -0.062315 -0.700154
# 215158  139960.0  1.821433  0.171955  0.176213  3.675559 -0.095810  0.944961
# 72476    54723.0  0.683389 -0.940750 -0.032823  0.352668 -0.898172 -1.047873
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 45064   0.192409  0.358037 -1.152046  ...  0.129241  0.420028 -0.001738
# 221763  0.622070 -0.124218  0.194063  ...  0.351643  1.273933 -0.196115
# 184315  0.288418 -0.516192 -2.328016  ...  0.293423  0.661183 -0.456360
# 215158 -0.704502  0.368977 -0.476102  ...  0.219130  0.646934  0.216581
# 72476   0.440964 -0.293963  0.178112  ... -0.045068 -0.877869 -0.160987
#
#              V24       V25       V26       V27       V28  Amount  Class
# 45064   0.964874 -0.242892  0.019006 -0.089094  0.086264   15.17    0.0
# 221763 -1.500324  0.454741  1.183228 -0.107911 -0.126564   17.50    0.0
# 184315  0.157349  0.611394  0.257373 -0.136026 -0.047552  304.20    0.0
# 215158  0.729428 -0.266932 -0.026518  0.004643 -0.033754    9.62    0.0
# 72476   0.432490  0.041511  0.783159 -0.148393  0.058986  319.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0    409
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1       V2        V3        V4        V5  \
# Class
# 0.0    77393.380081 -0.002169 -0.02903  0.283211  0.006009 -0.148619
# 1.0    65815.268949 -5.435534  4.00080 -7.507748  4.668153 -3.834575
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.104646 -0.063055  0.034808 -0.080786  ... -0.020154 -0.024676
# 1.0   -1.359844 -6.326941  0.653534 -2.699718  ...  0.387290  0.772642
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.041594 -0.031767 -0.064913  0.080423 -0.002702  0.008578 -0.002711
# 1.0    0.009933 -0.054624 -0.082548  0.051201  0.041523  0.194965  0.060572
#
#            Amount
# Class
# 0.0     90.434451
# 1.0    126.098924
#
# [2 rows x 30 columns]

# %%
x = new_dataset.drop(columns='Class',axis=1)
y = new_dataset['Class']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(x_train)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_train_pred,y_train)
print('Training Data Accuracy: ', score)
# Out:
# Training Data Accuracy:  0.9597222222222223

# %%
y_test_pred = model.predict(x_test)
score = accuracy_score(y_test_pred,y_test)
print('Testing Data Accuracy:',score)
# Out:
# Testing Data Accuracy: 0.9392265193370166
